# %%
from functions import *

# %%
fgsm: list = np.loadtxt('res/fgsm_accuracies.txt', delimiter = ' ').tolist()

plt.figure()
plt.plot(settings.epsilons, fgsm, marker = 'o', color = 'r')
plt.suptitle('Performance del modello ResNet-50 contro l\'attacco FGSM')
plt.xlabel('Epsilon')
plt.ylabel('Accuracy')
plt.xticks(np.arange(0, 1.1, step = 0.1))
plt.yticks(np.arange(0, 1.1, step = 0.1))
plt.grid()

# %%
ifgsm_5_iters: list = np.loadtxt('res/ifgsm_accuracies_5iters.txt', delimiter = ' ').tolist()
ifgsm_10_iters: list = np.loadtxt('res/ifgsm_accuracies_10iters.txt', delimiter = ' ').tolist()
ifgsm_25_iters: list = np.loadtxt('res/ifgsm_accuracies_25iters.txt', delimiter = ' ').tolist()
ifgsm_50_iters: list = np.loadtxt('res/ifgsm_accuracies_50iters.txt', delimiter = ' ').tolist()
ifgsm_75_iters: list = np.loadtxt('res/ifgsm_accuracies_75iters.txt', delimiter = ' ').tolist()
ifgsm_100_iters: list = np.loadtxt('res/ifgsm_accuracies_100iters.txt', delimiter = ' ').tolist()

plt.figure()
plt.plot(settings.epsilons, ifgsm_5_iters, label = 'iters = 5', marker = 'o', color = 'y')
plt.plot(settings.epsilons, ifgsm_10_iters, label = 'iters = 10', marker = 'o', color = 'g')
plt.plot(settings.epsilons, ifgsm_25_iters, label = 'iters = 25', marker = 'o', color = 'b')
plt.plot(settings.epsilons, ifgsm_50_iters, label = 'iters = 50', marker = 'o', color = 'm')
plt.plot(settings.epsilons, ifgsm_75_iters, label = 'iters = 75', marker = 'o', color = 'c')
plt.plot(settings.epsilons, ifgsm_100_iters, label = 'iters = 100', marker = 'o', color = 'r')
plt.legend(loc = 'lower left')
plt.suptitle('Performance del modello ResNet-50 contro l\'attacco I-FGSM')
plt.xlabel('Epsilon')
plt.ylabel('Accuracy')
plt.xticks(np.arange(0, 1.1, step = 0.1))
plt.yticks(np.arange(0, 1.1, step = 0.1))
plt.grid()

# %%
pgd_5_iters: list = np.loadtxt('res/pgd_accuracies_5iters.txt', delimiter = ' ').tolist()
pgd_10_iters: list = np.loadtxt('res/pgd_accuracies_10iters.txt', delimiter = ' ').tolist()
pgd_25_iters: list = np.loadtxt('res/pgd_accuracies_25iters.txt', delimiter = ' ').tolist()
pgd_50_iters: list = np.loadtxt('res/pgd_accuracies_50iters.txt', delimiter = ' ').tolist()
pgd_75_iters: list = np.loadtxt('res/pgd_accuracies_75iters.txt', delimiter = ' ').tolist()
pgd_100_iters: list = np.loadtxt('res/pgd_accuracies_100iters.txt', delimiter = ' ').tolist()

plt.figure()
plt.plot(settings.epsilons, pgd_5_iters, label = 'iters = 5', marker = 'o', color = 'y')
plt.plot(settings.epsilons, pgd_10_iters, label = 'iters = 10', marker = 'o', color = 'g')
plt.plot(settings.epsilons, pgd_25_iters, label = 'iters = 25', marker = 'o', color = 'b')
plt.plot(settings.epsilons, pgd_50_iters, label = 'iters = 50', marker = 'o', color = 'm')
plt.plot(settings.epsilons, pgd_75_iters, label = 'iters = 75', marker = 'o', color = 'c')
plt.plot(settings.epsilons, pgd_100_iters, label = 'iters = 100', marker = 'o', color = 'r')
plt.legend()
plt.suptitle('Performance del modello ResNet-50 contro l\'attacco PGD')
plt.xlabel('Epsilon')
plt.ylabel('Accuracy')
plt.xticks(np.arange(0, 1.1, step = 0.1))
plt.yticks(np.arange(0, 1.1, step = 0.1))
plt.grid()
